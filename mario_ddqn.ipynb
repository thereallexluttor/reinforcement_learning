# %%
import gym
from nes_py.wrappers import JoypadSpace #A
import gym_super_mario_bros
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT, COMPLEX_MOVEMENT #B
env = gym_super_mario_bros.make('SuperMarioBros-v0')
env = JoypadSpace(env, COMPLEX_MOVEMENT) #C
# Out:
# c:\Users\Mauri\anaconda3\envs\artyfal\lib\site-packages\gym\envs\registration.py:555: UserWarning: WARN: The environment SuperMarioBros-v0 is out of date. You should consider upgrading to version `v3`.
#   logger.warn(

# %%
done = True
for step in range(2500): #D
    if done:
        state = env.reset()
    state, reward, done, info = env.step(env.action_space.sample())
    env.render()
env.close()

# %%
from nes_py.wrappers import JoypadSpace
import gym_super_mario_bros
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT
import gym

env = gym.make('SuperMarioBros-v0')
env = JoypadSpace(env, SIMPLE_MOVEMENT)

done = True
#env.reset()
#for step in range(5000):
#    action = env.action_space.sample()
#    obs, reward, terminated, truncated, info = env.step(action)
#    done = terminated or truncated

#    if done:
#       env.reset()

#env.close()

# %%
import matplotlib.pyplot as plt
from skimage.transform import resize #A
import numpy as np

def downscale_obs(obs, new_size=(42,42), to_gray=True):
    if to_gray:
        return resize(obs, new_size, anti_aliasing=True).max(axis=2) #B
    else:
        return resize(obs, new_size, anti_aliasing=True)

# %%
env.reset()
env_screen = env.render(mode = 'rgb_array')
#env.close()

import matplotlib.pyplot as plt 
plt.imshow(env_screen)

# %%
plt.imshow(downscale_obs(env.render("rgb_array")))

# %%
obs = env.reset()
img = env.render()
plt.imshow(img)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 obs = env.reset()
#       2 img = env.render()
#       3 plt.imshow(img)
#
# File c:\Users\Mauri\anaconda3\envs\artyfal\lib\site-packages\nes_py\wrappers\joypad_space.py:78, in JoypadSpace.reset(self)
#      76 def reset(self):
#      77     """Reset the environment and return the initial observation."""
# ---> 78     return self.env.reset()
#
# File c:\Users\Mauri\anaconda3\envs\artyfal\lib\site-packages\gym\wrappers\time_limit.py:68, in TimeLimit.reset(self, **kwargs)
#      59 """Resets the environment with :param:`**kwargs` and sets the number of steps elapsed to zero.
#      60
#      61 Args:
#    (...)
#      65     The reset environment
#      66 """
#      67 self._elapsed_steps = 0
# ---> 68 return self.env.reset(**kwargs)
#
# File c:\Users\Mauri\anaconda3\envs\artyfal\lib\site-packages\gym\wrappers\order_enforcing.py:42, in OrderEnforcing.reset(self, **kwargs)
#      40 """Resets the environment with `kwargs`."""
#      41 self._has_reset = True
# ---> 42 return self.env.reset(**kwargs)
#
# File c:\Users\Mauri\anaconda3\envs\artyfal\lib\site-packages\gym\wrappers\env_checker.py:47, in PassiveEnvChecker.reset(self, **kwargs)
#      45     return env_reset_passive_checker(self.env, **kwargs)
#      46 else:
# ---> 47     return self.env.reset(**kwargs)
#
# File c:\Users\Mauri\anaconda3\envs\artyfal\lib\site-packages\nes_py\nes_env.py:265, in NESEnv.reset(self, seed, options, return_info)
#     263 # reset the emulator
#     264 if self._has_backup:
# --> 265     self._restore()
#     266 else:
#     267     _LIB.Reset(self._env)
#
# File c:\Users\Mauri\anaconda3\envs\artyfal\lib\site-packages\nes_py\nes_env.py:220, in NESEnv._restore(self)
#     218 def _restore(self):
#     219     """Restore the backup state into the NES emulator."""
# --> 220     _LIB.Restore(self._env)
#
# OSError: exception: access violation reading 0x000000000003C200
